# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import chardet

# %%
file = 'Speed+Dating+Data.csv'

# %%
# detect file encoding

with open(file, 'rb') as f:
    data = f.read()

# Detect the encoding
result = chardet.detect(data)
print(result['encoding'])
# Out:
# Windows-1252

# %%
data = pd.read_csv(file, encoding=result['encoding'])
df = pd.DataFrame(data)

# %%
df.sample(30)
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 2007  148   7.0       0   13       2     7     16         2       2.0      3
# 1521  104  11.0       1   22       2     4     18         2       NaN      7
# 7006  474   9.0       0   17       2    19     15         8       9.0     13
# 769    53  14.0       1   28       2     2     19        16       NaN      4
# 3090  218   5.0       1   10       2     9     20         5      19.0      7
# 6440  417   2.0       0    3       1    16      8         8       8.0      2
# 2650  196   3.0       0    5       2     9     20         5       5.0     10
# 5529  368   8.0       1   16       2    14     20        10      10.0      8
# 137    14   4.0       1    8       1     1     10        10       NaN      8
# 4044  274   2.0       1    4       2    11     21        15      15.0      9
# 5887  386   8.0       0   15       2    15     19        14      14.0     10
# ...

# %%
df.describe(include='all')
# Out:
#                 iid           id       gender          idg       condtn  \
# count   8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     283.675937     8.960248     0.500597    17.327166     1.828837
# std      158.583367     5.491329     0.500029    10.940735     0.376673
# min        1.000000     1.000000     0.000000     1.000000     1.000000
# 25%      154.000000     4.000000     0.000000     8.000000     2.000000
# 50%      281.000000     8.000000     1.000000    16.000000     2.000000
# 75%      407.000000    13.000000     1.000000    26.000000     2.000000
# max      552.000000    22.000000     1.000000    44.000000     2.000000
#
#                wave        round     position     positin1        order  ...  \
# ...

# %%
df.columns
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'positin1', 'order',
#        ...
#        'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3', 'attr5_3',
#        'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'],
#       dtype='object', length=195)

# %%
df.shape
# Out:
# (8378, 195)

# %%
df.head(1000)
# Out:
#      iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0      1   1.0       0    1       1     1     10         7       NaN      4
# 1      1   1.0       0    1       1     1     10         7       NaN      3
# 2      1   1.0       0    1       1     1     10         7       NaN     10
# 3      1   1.0       0    1       1     1     10         7       NaN      5
# 4      1   1.0       0    1       1     1     10         7       NaN      7
# ..   ...   ...     ...  ...     ...   ...    ...       ...       ...    ...
# 995   74   9.0       1   18       1     3     10         2       NaN      7
# 996   74   9.0       1   18       1     3     10        10       NaN      5
# 997   74   9.0       1   18       1     3     10         1       NaN      6
# 998   75  10.0       1   20       1     3     10         5       NaN      6
# 999   75  10.0       1   20       1     3     10         4       NaN      5
#
# ...

# %% [markdown]
# Différencier le sexe de chaque participant.e

# %%
unique = df[['iid', 'gender']].drop_duplicates()
unique['genre'] = unique['gender'].map({0: 'Femmes', 1: 'Hommes'})

unique.sample(30)
# Out:
#       iid  gender   genre
# 2688  198       0  Femmes
# 988    74       1  Hommes
# 4648  308       1  Hommes
# 4746  315       1  Hommes
# 1871  137       1  Hommes
# 6804  454       0  Femmes
# 6122  399       1  Hommes
# 4326  288       1  Hommes
# 6784  452       1  Hommes
# 100    11       1  Hommes
# 2088  154       0  Femmes
# 170    18       1  Hommes
# 4954  334       1  Hommes
# 2708  199       0  Femmes
# 2648  196       0  Femmes
# 440    36       0  Femmes
# 878    63       0  Femmes
# 3801  263       0  Femmes
# 908    66       1  Hommes
# 2248  164       1  Hommes
# 7740  524       0  Femmes
# 5276  355       0  Femmes
# 4760  316       1  Hommes
# 3028  215       1  Hommes
# 7011  475       0  Femmes
# 6374  413       1  Hommes
# 4690  311       1  Hommes
# 1098   81       0  Femmes
# 6488  424       1  Hommes
# 6524  430       0  Femmes

# %%
counts = unique['genre'].value_counts().reset_index()
counts.columns = ['genre', 'count']
counts['pourcentage'] = (counts['count'] / counts['count'].sum() * 100).round(1)

counts.head()
# Out:
#     genre  count  pourcentage
# 0  Hommes    277         50.3
# 1  Femmes    274         49.7

# %%
fig = px.pie(
    counts,
    values='count',
    names='genre',
    title='Répartition Femmes/ Hommes',
    color='genre',
    color_discrete_map={'Femmes': '#D4537E', 'Hommes': '#378ADD'},
    hole=0.5
)
 
fig.update_traces(
    texttemplate='%{label}<br>%{value} (%{percent})',
    textposition='outside'
)
 
fig.update_layout(
    showlegend=False,
    title_font_size=18,
    margin=dict(t=60, b=40, l=40, r=40)
)
 
fig.show()
